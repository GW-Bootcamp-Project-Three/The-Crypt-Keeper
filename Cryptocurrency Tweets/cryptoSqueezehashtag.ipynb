# %%
# Dependencies
import tweepy
import json
import pandas as pd
import os

# %%
# Get the current working directory
orig_working_directory = os.getcwd()
print(orig_working_directory)
# Out:
# /Users/Taslemun/Desktop/Cryptocurrency Tweets

# %%
# In this case, we are changing it to six levels up
os.chdir(os.path.join('..','..','..','..','..','..'))

# %%
# Now, you can see the new working directory
curr_working_directory = os.getcwd()
os.getcwd()
# Out:
# '/'

# %%
# This will search for the config file in the working directory
# Be sure that your config file is in your root repo folder

from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
# api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())
api = tweepy.API(auth)

# %%
# Target User Account
user_account = "WhalePanda"

# %%
tweets = []

tweet_id = []
created_at = []
favorite_count = []
full_text = []
entities = []

# %%
# Iterate through the first 500 tweets
for tweet in tweepy.Cursor(api.user_timeline, 'WhalePanda', tweet_mode='extended').items(1000):
    tweets.append(tweet)

# %%
# Preview the tweets list
#tweets

# %%
# Loop through Tweets list and process data 
for t in tweets:
    tweet_id.append(t.id)
    created_at.append(t.created_at)
    favorite_count.append(t.favorite_count)
    full_text.append(t.full_text)
    entities.append(t.entities)

# %%
# Build a tweets DataFrame

tweets_df = pd.DataFrame({
    'Tweet ID': tweet_id,
    'Tweet Time': created_at,
    'Favorite Count': favorite_count,
    'Tweet Text': full_text    
    })

# %%
len(tweets_df)
# Out:
# 1000

# %%
# set DataFrame to not truncate
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)
# Out:
# <ipython-input-14-87a0d77213bf>:2: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
tweets_df.head()
# Out:
#               Tweet ID          Tweet Time  Favorite Count  \
# 0  1365362643280740355 2021-02-26 18:06:36  49
# 1  1365358411018305536 2021-02-26 17:49:46  56
# 2  1365303148114546689 2021-02-26 14:10:11  127
# 3  1365280518879723525 2021-02-26 12:40:16  0
# 4  1365035878675021833 2021-02-25 20:28:09  75
#
#                                                                                                                                                                                                                                                              Tweet Text
# 0  @IamNomad @CryptoCobain only if they were on a secret mission.
# 1  @CryptoCobain Who is Rambo Musk?
# 2  "I am shutting you down! You are no longer allowed to operate here!"\n"Cool but we actually blocked NY citizens years ago."\n"It doesn't matter! I rule that you're no longer allowed to provide your services to our citizens."\n"Whatevs"\nhttps://t.co/kQTnBcOWVt
# 3  RT @hodlhodl: Some great lending offers with 18-20% APR, find more at https://t.co/4w4U9NAx8S https://t.co/C9Kiqh6EFK
# 4  Sure, why not?\nhttps://t.co/JyBuN8y9lK

# %%
tweets_df
# Out:
#                 Tweet ID          Tweet Time  Favorite Count  \
# 0    1365362643280740355 2021-02-26 18:06:36  49
# 1    1365358411018305536 2021-02-26 17:49:46  56
# 2    1365303148114546689 2021-02-26 14:10:11  127
# 3    1365280518879723525 2021-02-26 12:40:16  0
# 4    1365035878675021833 2021-02-25 20:28:09  75
# ..                   ...                 ...  ..
# 995  1315969650799370249 2020-10-13 10:56:28  76
# 996  1315619818477944835 2020-10-12 11:46:22  0
# 997  1315619388905717765 2020-10-12 11:44:39  0
# 998  1315615859730153475 2020-10-12 11:30:38  2
# 999  1315582144018866176 2020-10-12 09:16:40  2
#
#                                                                                                                                                                                                                                                                                                               Tweet Text
# 0    @IamNomad @CryptoCobain only if they were on a secret mission.
# 1    @CryptoCobain Who is Rambo Musk?
# 2    "I am shutting you down! You are no longer allowed to operate here!"\n"Cool but we actually blocked NY citizens years ago."\n"It doesn't matter! I rule that you're no longer allowed to provide your services to our citizens."\n"Whatevs"\nhttps://t.co/kQTnBcOWVt
# 3    RT @hodlhodl: Some great lending offers with 18-20% APR, find more at https://t.co/4w4U9NAx8S https://t.co/C9Kiqh6EFK
# 4    Sure, why not?\nhttps://t.co/JyBuN8y9lK
# ..                                       ...
# 995  Good luck with that.\nhttps://t.co/u0bXHyugkm
# 996  @carribeanpeanut Actually the best explanation so far that I've heard is that a lot of those smaller villages have kids that study in Brussels and even though they get it in Brussels, it still counts as an infection in the city where they live.
# 997  @carribeanpeanut I find the information interesting. There are more infections in the French speaking areas in Canada &amp; Switzerland as well compared to the rest of those countries.\nDon't you find it interesting? I'm not nationalistic Flemish guy. If it were up to me, I would live somewhere else😅
# 998  @eumartinez20 @CarstenBKK Yes and I would never promote nationalism. I don't like Belgium. The only reason I'm still living here is so that my kids could be close to their grandparents.\nI genuinely find it interesting since they're seeing the same in French speaking Canada and French speaking Switzerland.
# 999  @TanukiBTC @xDayKami https://t.co/4keyXW1OZf
#
# [1000 rows x 4 columns]

# %%
#tweets_df.to_excel('bowser_tweets.xlsx')
#entities

# %%
hashtag_entries = [e['hashtags'] for e in entities]
hashtag_entries
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [80, 88]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [40, 48]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [111, 119]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [50, 58]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [14, 22]}],
#  [{'text': 'Bitcoin', 'indices': [225, 233]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'btc', 'indices': [31, 35]},
#   {'text': 'cryptocurrencies', 'indices': [116, 133]}],
#  [{'text': 'Bitcoin', 'indices': [29, 37]}],
#  [{'text': 'Bitcoin', 'indices': [34, 42]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [72, 80]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [77, 85]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [{'text': 'Bitcoin', 'indices': [58, 66]}],
#  [{'text': 'Bitcoin', 'indices': [32, 40]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [76, 84]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [49, 57]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [67, 75]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [137, 145]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [55, 63]}],
#  [{'text': 'Bitcoin', 'indices': [55, 63]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [52, 60]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [58, 66]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [82, 90]}],
#  [{'text': 'Bitcoin', 'indices': [41, 49]}],
#  [{'text': 'Bitcoin', 'indices': [20, 28]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [35, 43]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [36, 44]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [27, 35]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [205, 213]}],
#  [{'text': 'Bitcoin', 'indices': [212, 220]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [104, 112]}],
#  [{'text': 'silver', 'indices': [26, 33]},
#   {'text': 'Bitcoin', 'indices': [82, 90]},
#   {'text': 'silvershortsqueeze', 'indices': [92, 111]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [38, 46]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [66, 74]}],
#  [{'text': 'Bitcoin', 'indices': [94, 102]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [83, 91]}],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [127, 135]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [14, 22]}],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [50, 58]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [64, 72]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [31, 39]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [22, 30]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [35, 43]}],
#  [{'text': 'Bitcoin', 'indices': [243, 251]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [68, 76]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [37, 45]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [205, 213]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [49, 57]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [83, 91]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [28, 36]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [98, 106]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [78, 86]}],
#  [],
#  [],
#  [{'text': 'DeFi', 'indices': [0, 5]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [13, 21]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [{'text': 'Bitcoin', 'indices': [8, 16]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [198, 206]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [59, 67]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [29, 37]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [12, 20]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [11, 19]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [22, 30]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [66, 74]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [33, 41]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [25, 33]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Tether', 'indices': [28, 35]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [57, 65]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [69, 77]},
#   {'text': 'Bitcoin', 'indices': [124, 132]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [11, 19]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [123, 131]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [55, 63]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [40, 48]}],
#  [{'text': 'Bitcoin', 'indices': [64, 72]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [81, 89]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [22, 30]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [268, 276]}],
#  [{'text': 'XRPTheSecurity', 'indices': [34, 49]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [8, 16]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [177, 185]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [128, 136]}],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [110, 118]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [34, 42]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [{'text': 'Bitcoin', 'indices': [86, 94]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [243, 251]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [93, 101]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [37, 45]}],
#  [{'text': 'Bitcoin', 'indices': [45, 53]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [31, 39]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [92, 100]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [25, 33]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [18, 26]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [30, 38]}],
#  [{'text': 'Bitcoin', 'indices': [63, 71]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [67, 75]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [5, 13]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [93, 101]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [33, 41]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [6, 14]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [51, 59]}],
#  [{'text': 'Bitcoin', 'indices': [63, 71]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [150, 158]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [25, 33]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [36, 44]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [66, 74]}],
#  [{'text': 'Bitcoin', 'indices': [19, 27]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [38, 46]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [28, 36]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'bitcoin', 'indices': [72, 80]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [41, 49]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [5, 13]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [5, 13]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [93, 101]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [58, 66]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [32, 40]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [144, 152]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [94, 102]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [151, 159]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [72, 80]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [61, 69]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'bitcoin', 'indices': [72, 80]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [102, 110]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [73, 81]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [50, 58]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [45, 53]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [11, 19]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
hashtags = []

for h in hashtag_entries:
    for t in h:
        hashtags.append(t['text'])
        
hashtags
# Out:
# ['Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'btc',
#  'cryptocurrencies',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'silver',
#  'Bitcoin',
#  'silvershortsqueeze',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'DeFi',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Tether',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'XRPTheSecurity',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin',
#  'Bitcoin']

# %%
hashtag_entries
# Out:
# [[],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [80, 88]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [40, 48]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [111, 119]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [50, 58]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [14, 22]}],
#  [{'text': 'Bitcoin', 'indices': [225, 233]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'btc', 'indices': [31, 35]},
#   {'text': 'cryptocurrencies', 'indices': [116, 133]}],
#  [{'text': 'Bitcoin', 'indices': [29, 37]}],
#  [{'text': 'Bitcoin', 'indices': [34, 42]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [72, 80]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [77, 85]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [{'text': 'Bitcoin', 'indices': [58, 66]}],
#  [{'text': 'Bitcoin', 'indices': [32, 40]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [76, 84]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [49, 57]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [67, 75]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [137, 145]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [55, 63]}],
#  [{'text': 'Bitcoin', 'indices': [55, 63]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [52, 60]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [58, 66]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [82, 90]}],
#  [{'text': 'Bitcoin', 'indices': [41, 49]}],
#  [{'text': 'Bitcoin', 'indices': [20, 28]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [35, 43]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [36, 44]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [27, 35]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [205, 213]}],
#  [{'text': 'Bitcoin', 'indices': [212, 220]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [104, 112]}],
#  [{'text': 'silver', 'indices': [26, 33]},
#   {'text': 'Bitcoin', 'indices': [82, 90]},
#   {'text': 'silvershortsqueeze', 'indices': [92, 111]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [38, 46]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [66, 74]}],
#  [{'text': 'Bitcoin', 'indices': [94, 102]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [83, 91]}],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [127, 135]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [14, 22]}],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [50, 58]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [64, 72]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [31, 39]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [22, 30]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [35, 43]}],
#  [{'text': 'Bitcoin', 'indices': [243, 251]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [68, 76]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [37, 45]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [205, 213]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [49, 57]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [83, 91]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [28, 36]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [98, 106]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [78, 86]}],
#  [],
#  [],
#  [{'text': 'DeFi', 'indices': [0, 5]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [13, 21]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [{'text': 'Bitcoin', 'indices': [8, 16]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [198, 206]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [59, 67]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [29, 37]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [12, 20]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [11, 19]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [22, 30]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [66, 74]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [33, 41]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [25, 33]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Tether', 'indices': [28, 35]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [57, 65]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [69, 77]},
#   {'text': 'Bitcoin', 'indices': [124, 132]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [11, 19]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [123, 131]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [55, 63]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [40, 48]}],
#  [{'text': 'Bitcoin', 'indices': [64, 72]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [24, 32]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [81, 89]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [22, 30]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [268, 276]}],
#  [{'text': 'XRPTheSecurity', 'indices': [34, 49]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [8, 16]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [177, 185]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [128, 136]}],
#  [{'text': 'Bitcoin', 'indices': [0, 8]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [110, 118]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [34, 42]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [{'text': 'Bitcoin', 'indices': [86, 94]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [243, 251]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [93, 101]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [37, 45]}],
#  [{'text': 'Bitcoin', 'indices': [45, 53]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [31, 39]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [92, 100]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [25, 33]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [18, 26]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [30, 38]}],
#  [{'text': 'Bitcoin', 'indices': [63, 71]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [67, 75]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [5, 13]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [93, 101]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [33, 41]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [6, 14]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [51, 59]}],
#  [{'text': 'Bitcoin', 'indices': [63, 71]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [21, 29]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [150, 158]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [25, 33]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [36, 44]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [66, 74]}],
#  [{'text': 'Bitcoin', 'indices': [19, 27]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [38, 46]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [28, 36]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'bitcoin', 'indices': [72, 80]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [16, 24]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [41, 49]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [5, 13]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [43, 51]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [5, 13]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [93, 101]}],
#  [],
#  [{'text': 'Bitcoin', 'indices': [58, 66]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [32, 40]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [144, 152]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [94, 102]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [151, 159]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [72, 80]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [61, 69]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'bitcoin', 'indices': [72, 80]}],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [102, 110]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [56, 64]}],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [73, 81]}],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [50, 58]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [45, 53]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'text': 'Bitcoin', 'indices': [11, 19]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  []]

# %%
hashtags_series = pd.Series(hashtags)

# %%
tweet_counts = hashtags_series.value_counts()
tweet_counts
# Out:
# Bitcoin               146
# bitcoin               2
# silver                1
# cryptocurrencies      1
# Tether                1
# DeFi                  1
# silvershortsqueeze    1
# XRPTheSecurity        1
# btc                   1
# dtype: int64

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(figsize=(6, 8))

tweet_plot = tweet_counts.plot(kind='barh')
tweet_plot.invert_yaxis()

# %%
tweet_counts.sum()
# Out:
# 155
